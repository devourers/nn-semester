# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import string

import sklearn.

# %%
# %%capture
# !wget https://www.dropbox.com/s/jaea4smqjbmslsb/training_data.csv
# !wget https://www.dropbox.com/s/y1i45d72k9byzak/test_data.csv

# %%
training_data = pd.read_csv('training_data.csv')

# %%
training_data.sample(10, random_state=123)
# Out:
#       Age     BusinessTravel              Department  DistanceFromHome  \
# 1930   45         Non-Travel                   Sales                 2
# 909    35      Travel_Rarely  Research & Development                 9
# 222    30  Travel_Frequently  Research & Development                 9
# 2307   33      Travel_Rarely  Research & Development                 9
# 576    34      Travel_Rarely                   Sales                 1
# 1984   56  Travel_Frequently  Research & Development                 1
# 2984   28      Travel_Rarely  Research & Development                 9
# 2942   32  Travel_Frequently  Research & Development                17
# 43     18      Travel_Rarely                   Sales                 7
# 2880   38      Travel_Rarely                   Sales                 8
#
#       Education EducationField  Gender                    JobRole  \
# 1930          3        Medical  Female            Sales Executive
# ...

# %%
td_male_midage_sales = (training_data['Age'] >= 25) & (training_data['Age'] <= 35) & (training_data['Gender'] == 'Male') & (training_data['JobRole'].str.find('Sales') != -1)

# %%
training_data[td_male_midage_sales].head()
# Out:
#     Age     BusinessTravel              Department  DistanceFromHome  \
# 2    32  Travel_Frequently  Research & Development                17
# 4    32      Travel_Rarely  Research & Development                10
# 6    28      Travel_Rarely  Research & Development                11
# 7    29      Travel_Rarely  Research & Development                18
# 18   35      Travel_Rarely                   Sales                 7
#
#     Education EducationField Gender               JobRole MaritalStatus  \
# 2           4          Other   Male       Sales Executive       Married
# 4           1        Medical   Male       Sales Executive        Single
# 6           2        Medical   Male       Sales Executive        Single
# 7           3  Life Sciences   Male       Sales Executive       Married
# 18          4  Life Sciences   Male  Sales Representative      Divorced
#
#     MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  StandardHours  \
# ...

# %%
td_female_midage_sales = (training_data['Age'] >= 25) & (training_data['Age'] <= 35) & (training_data['Gender'] == 'Female') & (training_data['JobRole'].str.find('Sales') != -1)

# %%
training_data[td_female_midage_sales].head()
# Out:
#      Age     BusinessTravel              Department  DistanceFromHome  \
# 114   35      Travel_Rarely  Research & Development                29
# 161   30         Non-Travel  Research & Development                15
# 180   35      Travel_Rarely  Research & Development                12
# 181   31  Travel_Frequently  Research & Development                22
# 189   35      Travel_Rarely  Research & Development                22
#
#      Education EducationField  Gender               JobRole MaritalStatus  \
# 114          3  Life Sciences  Female       Sales Executive        Single
# 161          3        Medical  Female       Sales Executive       Married
# 180          2        Medical  Female  Sales Representative       Married
# 181          2        Medical  Female       Sales Executive       Married
# 189          3        Medical  Female  Sales Representative       Married
#
#      MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  StandardHours  \
# ...

# %%
training_data.describe().T
# Out:
#                           count          mean           std      min      25%  \
# Age                      3308.0     36.879383      9.146506     18.0     30.0
# DistanceFromHome         3308.0      9.201935      8.078147      1.0      2.0
# Education                3308.0      2.918380      1.024933      1.0      2.0
# MonthlyIncome            3308.0  64594.903265  46744.260986  10090.0  29040.0
# NumCompaniesWorked       3293.0      2.703310      2.506197      0.0      1.0
# PercentSalaryHike        3308.0     15.230048      3.672812     11.0     12.0
# StandardHours            3308.0      8.000000      0.000000      8.0      8.0
# StockOptionLevel         3308.0      0.804716      0.860350      0.0      0.0
# TotalWorkingYears        3301.0     11.283248      7.791024      0.0      6.0
# TrainingTimesLastYear    3308.0      2.801995      1.290718      0.0      2.0
# YearsAtCompany           3308.0      6.998791      6.135502      0.0      3.0
# ...

# %%
training_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3308 entries, 0 to 3307
# Data columns (total 20 columns):
# Age                        3308 non-null int64
# BusinessTravel             3308 non-null object
# Department                 3308 non-null object
# DistanceFromHome           3308 non-null int64
# Education                  3308 non-null int64
# EducationField             3308 non-null object
# Gender                     3308 non-null object
# JobRole                    3308 non-null object
# MaritalStatus              3308 non-null object
# MonthlyIncome              3308 non-null int64
# NumCompaniesWorked         3293 non-null float64
# PercentSalaryHike          3308 non-null int64
# StandardHours              3308 non-null int64
# StockOptionLevel           3308 non-null int64
# TotalWorkingYears          3301 non-null float64
# TrainingTimesLastYear      3308 non-null int64
# YearsAtCompany             3308 non-null int64
# ...

# %%
training_mean = training_data.mean()

# %%
training_mean
# Out:
# Age                           36.879383
# DistanceFromHome               9.201935
# Education                      2.918380
# MonthlyIncome              64594.903265
# NumCompaniesWorked             2.703310
# PercentSalaryHike             15.230048
# StandardHours                  8.000000
# StockOptionLevel               0.804716
# TotalWorkingYears             11.283248
# TrainingTimesLastYear          2.801995
# YearsAtCompany                 6.998791
# YearsSinceLastPromotion        2.187122
# YearsWithCurrManager           4.118501
# Attrition                      0.160218
# dtype: float64

# %%
ta = training_data.fillna(training_mean, inplace = True)

# %%
training_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3308 entries, 0 to 3307
# Data columns (total 20 columns):
# Age                        3308 non-null int64
# BusinessTravel             3308 non-null object
# Department                 3308 non-null object
# DistanceFromHome           3308 non-null int64
# Education                  3308 non-null int64
# EducationField             3308 non-null object
# Gender                     3308 non-null object
# JobRole                    3308 non-null object
# MaritalStatus              3308 non-null object
# MonthlyIncome              3308 non-null int64
# NumCompaniesWorked         3308 non-null float64
# PercentSalaryHike          3308 non-null int64
# StandardHours              3308 non-null int64
# StockOptionLevel           3308 non-null int64
# TotalWorkingYears          3308 non-null float64
# TrainingTimesLastYear      3308 non-null int64
# YearsAtCompany             3308 non-null int64
# ...

# %%
training_data['MonthlyIncome'].mean()
# Out:
# 64594.90326481257

# %%
test_data = pd.read_csv('test_data.csv')

# %%
target_var = 'Attrition'

# %%
training_values = training_data[target_var]
training_values.value_counts()
# Out:
# 0    2778
# 1     530
# Name: Attrition, dtype: int64

# %%
training_points = training_data.drop(target_var, axis = 1)

# %%
training_points
# Out:
#       Age     BusinessTravel              Department  DistanceFromHome  \
# 0      51      Travel_Rarely                   Sales                 6
# 1      31  Travel_Frequently  Research & Development                10
# 2      32  Travel_Frequently  Research & Development                17
# 3      38         Non-Travel  Research & Development                 2
# 4      32      Travel_Rarely  Research & Development                10
# 5      46      Travel_Rarely  Research & Development                 8
# 6      28      Travel_Rarely  Research & Development                11
# 7      29      Travel_Rarely  Research & Development                18
# 8      31      Travel_Rarely  Research & Development                 1
# 9      25         Non-Travel  Research & Development                 7
# 10     45      Travel_Rarely  Research & Development                17
# 11     36      Travel_Rarely  Research & Development                28
# ...

# %%
test_values = test_data[target_var]

# %%
test_points = test_data.drop(target_var, axis = 1)

# %%
dummies = pd.get_dummies(data = training_points)
